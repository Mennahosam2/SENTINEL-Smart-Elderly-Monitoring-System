# %%
import tensorflow as tf
print("GPUs:", tf.config.list_physical_devices("GPU"))

from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")
print("Mixed precision policy:", mixed_precision.global_policy())
# Out:
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Mixed precision policy: <DTypePolicy "mixed_float16">

# %%
from google.colab import drive
drive.mount("/content/drive")

import os

drive_dir = "/content/drive/MyDrive/mimic_bp"
work_dir  = "/content/mimic_bp"
os.makedirs(work_dir, exist_ok=True)

MODALITY   = "ecg"   # "ecg" or "ppg" or "resp"
MODEL_TYPE = "lstm"   # "cnn" or "lstm"

run_name = f"{MODALITY.upper()}_{MODEL_TYPE.upper()}"
ckpt_dir = os.path.join(drive_dir, "single_modality_runs", run_name)
os.makedirs(ckpt_dir, exist_ok=True)

print("run_name:", run_name)
print("ckpt_dir:", ckpt_dir)
# Out:
# Mounted at /content/drive
# run_name: ECG_LSTM
# ckpt_dir: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM

# %%
import shutil, zipfile

zips = ["abp", "ecg", "ppg", "resp", "labels"]

for name in zips:
    out_dir = os.path.join(work_dir, name)
    if os.path.exists(out_dir) and len(os.listdir(out_dir)) > 0:
        print(f" {name} already extracted.")
        continue

    src = os.path.join(drive_dir, f"{name}.zip")
    dst = os.path.join(work_dir,  f"{name}.zip")
    if not os.path.exists(src):
        raise FileNotFoundError(f"Missing: {src}")

    print("Copying", src, "->", dst)
    shutil.copy(src, dst)

    os.makedirs(out_dir, exist_ok=True)
    print("Unzipping", dst, "->", out_dir)
    with zipfile.ZipFile(dst, "r") as z:
        z.extractall(out_dir)

base_dir = work_dir
print("base_dir:", base_dir)
# Out:
# Copying /content/drive/MyDrive/mimic_bp/abp.zip -> /content/mimic_bp/abp.zip
# Unzipping /content/mimic_bp/abp.zip -> /content/mimic_bp/abp
# Copying /content/drive/MyDrive/mimic_bp/ecg.zip -> /content/mimic_bp/ecg.zip
# Unzipping /content/mimic_bp/ecg.zip -> /content/mimic_bp/ecg
# Copying /content/drive/MyDrive/mimic_bp/ppg.zip -> /content/mimic_bp/ppg.zip
# Unzipping /content/mimic_bp/ppg.zip -> /content/mimic_bp/ppg
# Copying /content/drive/MyDrive/mimic_bp/resp.zip -> /content/mimic_bp/resp.zip
# Unzipping /content/mimic_bp/resp.zip -> /content/mimic_bp/resp
# Copying /content/drive/MyDrive/mimic_bp/labels.zip -> /content/mimic_bp/labels.zip
# Unzipping /content/mimic_bp/labels.zip -> /content/mimic_bp/labels
# base_dir: /content/mimic_bp

# %%
import ast, os

def load_ids_fixed(path: str):
    if not os.path.exists(path):
        raise FileNotFoundError(f"Missing split file: {path}")
    with open(path, "r") as f:
        t = f.read().strip()
    if t.startswith("[") and t.endswith("]"):
        return ast.literal_eval(t)
    return [line.strip() for line in t.splitlines() if line.strip()]

train_ids = load_ids_fixed(os.path.join(drive_dir, "train_subjects.txt"))
val_ids   = load_ids_fixed(os.path.join(drive_dir, "val_subjects.txt"))
test_ids  = load_ids_fixed(os.path.join(drive_dir, "test_subjects.txt"))

print("Subjects:", {"train": len(train_ids), "val": len(val_ids), "test": len(test_ids)})

print("Overlap train/val :", len(set(train_ids) & set(val_ids)))
print("Overlap train/test:", len(set(train_ids) & set(test_ids)))
print("Overlap val/test  :", len(set(val_ids) & set(test_ids)))

N = len(train_ids) + len(val_ids) + len(test_ids)
print("Split ratio (%):", {
    "train": round(100*len(train_ids)/N, 2),
    "val"  : round(100*len(val_ids)/N, 2),
    "test" : round(100*len(test_ids)/N, 2),
})
# Out:
# Subjects: {'train': 1100, 'val': 195, 'test': 229}
# Overlap train/val : 0
# Overlap train/test: 0
# Overlap val/test  : 0
# Split ratio (%): {'train': 72.18, 'val': 12.8, 'test': 15.03}

# %%
import numpy as np
import tensorflow as tf

WINDOW_LEN = 1250
STRIDE     = 1250
BATCH      = 64

def sliding_windows_1d(x, win_len, stride):
    L = len(x)
    if L < win_len:
        return np.empty((0, win_len), dtype=x.dtype)
    starts = range(0, L - win_len + 1, stride)
    return np.stack([x[s:s+win_len] for s in starts], axis=0)

def gen_from_ids(subject_ids, modality):
    sig_dir    = os.path.join(base_dir, modality)
    labels_dir = os.path.join(base_dir, "labels")

    for sid in subject_ids:
        sig_path = os.path.join(sig_dir,    f"{sid}_{modality}.npy")
        lab_path = os.path.join(labels_dir, f"{sid}_labels.npy")
        if not (os.path.exists(sig_path) and os.path.exists(lab_path)):
            continue

        sig    = np.load(sig_path)   # (30, 3750)
        labels = np.load(lab_path)   # (30, 2)

        for i in range(sig.shape[0]):
            y = labels[i].astype("float32")

            w = sliding_windows_1d(sig[i], WINDOW_LEN, STRIDE).astype("float32")  # (Nw, win)
            for k in range(w.shape[0]):
                x = w[k].reshape(WINDOW_LEN, 1)  # (win,1)
                if np.isfinite(x).all() and np.isfinite(y).all():
                    yield x, y

output_signature = (
    tf.TensorSpec(shape=(WINDOW_LEN, 1), dtype=tf.float32),
    tf.TensorSpec(shape=(2,), dtype=tf.float32),
)

train_ds = tf.data.Dataset.from_generator(lambda: gen_from_ids(train_ids, MODALITY), output_signature=output_signature)
val_ds   = tf.data.Dataset.from_generator(lambda: gen_from_ids(val_ids,   MODALITY), output_signature=output_signature)
test_ds  = tf.data.Dataset.from_generator(lambda: gen_from_ids(test_ids,  MODALITY), output_signature=output_signature)


train_ds = train_ds.shuffle(8000).batch(BATCH).prefetch(tf.data.AUTOTUNE).repeat()
val_ds   = val_ds.batch(BATCH).prefetch(tf.data.AUTOTUNE).repeat()
test_ds  = test_ds.batch(BATCH).prefetch(tf.data.AUTOTUNE)

print(" datasets ready:", MODALITY)
# Out:
#  datasets ready: ecg

# %%
import numpy as np
import tensorflow as tf

def estimate_mean_std(ds, num_batches=200):
    total = 0
    s  = 0.0
    s2 = 0.0
    for x, _ in ds.take(num_batches):
        a = x.numpy().reshape(-1)
        s  += a.sum()
        s2 += (a*a).sum()
        total += a.size
    mean = s / total
    var  = (s2 / total) - mean**2
    std  = np.sqrt(max(var, 1e-12)) + 1e-8
    return float(mean), float(std)

mean, std = estimate_mean_std(train_ds, num_batches=200)
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std,  dtype=tf.float32)

def norm_xy(x, y):
    return (x - mean_tf) / std_tf, y

train_data = train_ds.map(norm_xy, num_parallel_calls=tf.data.AUTOTUNE)
val_data   = val_ds.map(norm_xy,   num_parallel_calls=tf.data.AUTOTUNE)
test_data  = test_ds.map(norm_xy,  num_parallel_calls=tf.data.AUTOTUNE)

print(" Z-score mean/std (train-only):", mean, std)
# Out:
#  Z-score mean/std (train-only): 0.3563176691532135 0.2903037369251251

# %%
import time
import tensorflow as tf

EPOCHS          = 100
STEPS_PER_EPOCH = 250
VAL_STEPS       = 60
SAVE_EVERY_N    = 10

best_path = os.path.join(ckpt_dir, f"best_{run_name}.keras")

class TimeInLogs(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        self.t0 = time.time()
    def on_epoch_end(self, epoch, logs=None):
        if logs is not None:
            logs["time_sec"] = time.time() - self.t0

class SaveEveryN(tf.keras.callbacks.Callback):
    def __init__(self, n=10):
        super().__init__()
        self.n = n
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.n == 0:
            path = os.path.join(ckpt_dir, f"checkpoint_{run_name}_epoch_{epoch+1}.keras")
            self.model.save(path)
            print("\n Saved:", path)

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(best_path, save_best_only=True, monitor="val_loss"),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.5, min_lr=1e-6),
    TimeInLogs(),
    SaveEveryN(n=SAVE_EVERY_N),
]

print("best_path:", best_path)
# Out:
# best_path: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/best_ECG_LSTM.keras

# %%
import tensorflow as tf
from tensorflow.keras import layers

def build_model(model_type: str):
    if model_type == "cnn":
        return tf.keras.Sequential([
            layers.Input(shape=(WINDOW_LEN, 1)),
            layers.Conv1D(32, 7, padding="same"),
            layers.BatchNormalization(),
            layers.Activation("relu"),
            layers.MaxPooling1D(2),

            layers.Conv1D(64, 5, padding="same"),
            layers.BatchNormalization(),
            layers.Activation("relu"),
            layers.MaxPooling1D(2),

            layers.Conv1D(128, 3, padding="same"),
            layers.BatchNormalization(),
            layers.Activation("relu"),
            layers.GlobalAveragePooling1D(),

            layers.Dense(128, activation="relu"),
            layers.Dropout(0.3),
            layers.Dense(2, dtype="float32")
        ])

    if model_type == "lstm":
        return tf.keras.Sequential([
            layers.Input(shape=(WINDOW_LEN, 1)),
            layers.LSTM(64, return_sequences=True),
            layers.Dropout(0.2),
            layers.LSTM(64),
            layers.Dense(128, activation="relu"),
            layers.Dropout(0.3),
            layers.Dense(2, dtype="float32")
        ])

    raise ValueError("model_type must be 'cnn' or 'lstm'")

model = build_model(MODEL_TYPE)

model.compile(
    optimizer=tf.keras.optimizers.Adam(3e-4),
    loss=tf.keras.losses.Huber(delta=10.0),
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.MeanSquaredError(name="mse"),
    ],
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1250, 64)       │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1250, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,498 (228.51 KB)
#  Trainable params: 58,498 (228.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_steps=VAL_STEPS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 115ms/step - loss: 582.8727 - mae: 63.1844 - mse: 5232.8608 - val_loss: 263.9541 - val_mae: 30.8897 - val_mse: 1551.8068 - learning_rate: 3.0000e-04 - time_sec: 37.5217
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - loss: 139.3989 - mae: 18.2723 - mse: 597.5795 - val_loss: 82.1254 - val_mae: 12.2949 - val_mse: 259.4152 - learning_rate: 3.0000e-04 - time_sec: 27.4763
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 110ms/step - loss: 101.7182 - mae: 14.4125 - mse: 344.2105 - val_loss: 80.6889 - val_mae: 12.1711 - val_mse: 246.7914 - learning_rate: 3.0000e-04 - time_sec: 27.5820
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 102.6981 - mae: 14.4994 - mse: 351.0825 - val_loss: 81.0155 - val_mae: 12.1985 - val_mse: 250.9658 - learning_rate: 3.0000e-04 - time_sec: 27.0595
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - loss: 100.4955 - mae: 14.2797 - mse: 340.8984 - val_loss: 81.2614 - val_mae: 12.2197 - val_mse: 253.3858 - learning_rate: 3.0000e-04 - time_sec: 26.7393
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 103ms/step - loss: 98.0997 - mae: 14.0088 - mse: 331.2733 - val_loss: 80.7838 - val_mae: 12.1780 - val_mse: 247.3144 - learning_rate: 3.0000e-04 - time_sec: 25.6693
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 114ms/step - loss: 94.6713 - mae: 13.6428 - mse: 315.3357 - val_loss: 81.1336 - val_mae: 12.2205 - val_mse: 253.0856 - learning_rate: 3.0000e-04 - time_sec: 28.5548
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 100.0424 - mae: 14.2077 - mse: 339.9234 - val_loss: 81.2313 - val_mae: 12.2157 - val_mse: 252.7348 - learning_rate: 3.0000e-04 - time_sec: 27.0538
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 98.5689 - mae: 14.0815 - mse: 329.0344 - val_loss: 80.8582 - val_mae: 12.1863 - val_mse: 249.9679 - learning_rate: 1.5000e-04 - time_sec: 27.0804
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 100.8978 - mae: 14.3170 - mse: 338.2987
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_10.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - loss: 99.7018 - mae: 14.1776 - mse: 336.4028 - val_loss: 80.7866 - val_mae: 12.1789 - val_mse: 249.0070 - learning_rate: 1.5000e-04 - time_sec: 26.8578
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 98.1427 - mae: 14.0262 - mse: 328.2547 - val_loss: 80.8949 - val_mae: 12.1890 - val_mse: 250.1529 - learning_rate: 1.5000e-04 - time_sec: 26.8668
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 105ms/step - loss: 98.3392 - mae: 14.0357 - mse: 332.3065 - val_loss: 80.9209 - val_mae: 12.1908 - val_mse: 249.9913 - learning_rate: 1.5000e-04 - time_sec: 26.2272
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 110ms/step - loss: 95.3616 - mae: 13.7219 - mse: 316.7540 - val_loss: 81.7090 - val_mae: 12.2743 - val_mse: 257.6295 - learning_rate: 1.5000e-04 - time_sec: 27.5638
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 98.1721 - mae: 14.0109 - mse: 331.3499 - val_loss: 80.7738 - val_mae: 12.1775 - val_mse: 248.7383 - learning_rate: 7.5000e-05 - time_sec: 40.9087
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - loss: 98.8954 - mae: 14.1056 - mse: 331.6855 - val_loss: 81.7524 - val_mae: 12.2701 - val_mse: 257.8057 - learning_rate: 7.5000e-05 - time_sec: 26.7545
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 99.6609 - mae: 14.1882 - mse: 337.0270 - val_loss: 80.7041 - val_mae: 12.1719 - val_mse: 247.1938 - learning_rate: 7.5000e-05 - time_sec: 40.9006
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 98.1458 - mae: 14.0295 - mse: 330.4825 - val_loss: 80.6937 - val_mae: 12.1710 - val_mse: 246.9243 - learning_rate: 7.5000e-05 - time_sec: 41.0147
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - loss: 98.5452 - mae: 14.0688 - mse: 332.4552 - val_loss: 80.7169 - val_mae: 12.1689 - val_mse: 249.0889 - learning_rate: 7.5000e-05 - time_sec: 27.2034
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 111ms/step - loss: 95.1115 - mae: 13.6832 - mse: 316.6822 - val_loss: 81.3884 - val_mae: 12.2348 - val_mse: 255.9079 - learning_rate: 3.7500e-05 - time_sec: 27.7315
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 91.9419 - mae: 13.3433 - mse: 301.8887
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_20.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 95.0835 - mae: 13.6795 - mse: 316.9397 - val_loss: 80.7968 - val_mae: 12.1815 - val_mse: 250.7646 - learning_rate: 3.7500e-05 - time_sec: 27.7597
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - loss: 100.8715 - mae: 14.3127 - mse: 341.2292 - val_loss: 80.9149 - val_mae: 12.1859 - val_mse: 252.2725 - learning_rate: 3.7500e-05 - time_sec: 40.2930
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 99.0592 - mae: 14.1200 - mse: 332.9691 - val_loss: 80.6044 - val_mae: 12.1622 - val_mse: 245.9762 - learning_rate: 3.7500e-05 - time_sec: 27.8935
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 97.3252 - mae: 13.9256 - mse: 325.7022 - val_loss: 80.4915 - val_mae: 12.1456 - val_mse: 247.2275 - learning_rate: 3.7500e-05 - time_sec: 27.9450
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 111ms/step - loss: 98.4102 - mae: 14.0502 - mse: 331.5690 - val_loss: 80.7919 - val_mae: 12.1725 - val_mse: 251.0439 - learning_rate: 3.7500e-05 - time_sec: 27.8116
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 95.9101 - mae: 13.7870 - mse: 321.2687 - val_loss: 80.9232 - val_mae: 12.1883 - val_mse: 252.8930 - learning_rate: 3.7500e-05 - time_sec: 28.2073
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 111ms/step - loss: 94.1936 - mae: 13.5900 - mse: 312.6664 - val_loss: 80.7052 - val_mae: 12.1661 - val_mse: 251.8639 - learning_rate: 3.7500e-05 - time_sec: 27.6280
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - loss: 101.2032 - mae: 14.3529 - mse: 345.1038 - val_loss: 80.6879 - val_mae: 12.1594 - val_mse: 251.6493 - learning_rate: 3.7500e-05 - time_sec: 27.4795
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - loss: 96.3334 - mae: 13.8321 - mse: 317.9219 - val_loss: 80.3314 - val_mae: 12.1301 - val_mse: 243.7393 - learning_rate: 3.7500e-05 - time_sec: 27.2956
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 98.7020 - mae: 14.0758 - mse: 334.1383 - val_loss: 80.4973 - val_mae: 12.1414 - val_mse: 249.6486 - learning_rate: 3.7500e-05 - time_sec: 27.0773
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 100.0323 - mae: 14.2312 - mse: 335.2751
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_30.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 99.8561 - mae: 14.2141 - mse: 333.9576 - val_loss: 80.8884 - val_mae: 12.1777 - val_mse: 253.7662 - learning_rate: 3.7500e-05 - time_sec: 27.5874
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 96.3222 - mae: 13.7995 - mse: 326.7258 - val_loss: 80.4501 - val_mae: 12.1400 - val_mse: 247.2175 - learning_rate: 3.7500e-05 - time_sec: 28.1594
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 92.2758 - mae: 13.3955 - mse: 303.8260 - val_loss: 80.7459 - val_mae: 12.1714 - val_mse: 252.3989 - learning_rate: 3.7500e-05 - time_sec: 40.9613
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 101.6082 - mae: 14.3866 - mse: 347.3816 - val_loss: 80.5998 - val_mae: 12.1513 - val_mse: 250.5371 - learning_rate: 3.7500e-05 - time_sec: 40.9441
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 96.0245 - mae: 13.8089 - mse: 316.6938 - val_loss: 80.2516 - val_mae: 12.1173 - val_mse: 247.2872 - learning_rate: 1.8750e-05 - time_sec: 27.9699
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 111ms/step - loss: 98.9043 - mae: 14.0972 - mse: 334.7787 - val_loss: 80.3196 - val_mae: 12.1258 - val_mse: 247.0883 - learning_rate: 1.8750e-05 - time_sec: 27.8436
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 98.8782 - mae: 14.1220 - mse: 330.2598 - val_loss: 80.4928 - val_mae: 12.1395 - val_mse: 249.8879 - learning_rate: 1.8750e-05 - time_sec: 41.0209
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 104ms/step - loss: 96.1615 - mae: 13.7902 - mse: 323.6296 - val_loss: 80.2665 - val_mae: 12.1223 - val_mse: 246.1594 - learning_rate: 1.8750e-05 - time_sec: 26.0104
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 120ms/step - loss: 92.6853 - mae: 13.4439 - mse: 304.1259 - val_loss: 81.0738 - val_mae: 12.2039 - val_mse: 255.3220 - learning_rate: 1.8750e-05 - time_sec: 30.0415
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 100.8811 - mae: 14.2927 - mse: 344.6891 - val_loss: 80.4779 - val_mae: 12.1447 - val_mse: 249.1735 - learning_rate: 1.8750e-05 - time_sec: 27.8767
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 97.5544 - mae: 13.9669 - mse: 323.7357
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_40.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 114ms/step - loss: 97.0188 - mae: 13.9069 - mse: 321.4470 - val_loss: 80.5249 - val_mae: 12.1488 - val_mse: 249.8794 - learning_rate: 9.3750e-06 - time_sec: 27.9475
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 98.7615 - mae: 14.0843 - mse: 334.7287 - val_loss: 80.1238 - val_mae: 12.1080 - val_mse: 245.3100 - learning_rate: 9.3750e-06 - time_sec: 28.4300
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 116ms/step - loss: 97.9218 - mae: 14.0115 - mse: 327.6490 - val_loss: 80.1556 - val_mae: 12.1119 - val_mse: 246.3067 - learning_rate: 9.3750e-06 - time_sec: 28.8620
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - loss: 97.0334 - mae: 13.8896 - mse: 326.5760 - val_loss: 80.4756 - val_mae: 12.1428 - val_mse: 249.2075 - learning_rate: 9.3750e-06 - time_sec: 27.4174
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 117ms/step - loss: 93.1103 - mae: 13.4936 - mse: 305.6252 - val_loss: 80.7690 - val_mae: 12.1723 - val_mse: 252.5115 - learning_rate: 9.3750e-06 - time_sec: 29.2524
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 97.8149 - mae: 13.9739 - mse: 332.1354 - val_loss: 80.5396 - val_mae: 12.1500 - val_mse: 250.2644 - learning_rate: 9.3750e-06 - time_sec: 28.4421
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 97.5870 - mae: 13.9632 - mse: 325.2170 - val_loss: 80.6314 - val_mae: 12.1587 - val_mse: 251.2193 - learning_rate: 9.3750e-06 - time_sec: 28.3028
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 99.7782 - mae: 14.1923 - mse: 337.8917 - val_loss: 80.3844 - val_mae: 12.1359 - val_mse: 247.9421 - learning_rate: 4.6875e-06 - time_sec: 28.2497
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 97.8363 - mae: 13.9959 - mse: 327.1450 - val_loss: 80.3869 - val_mae: 12.1359 - val_mse: 248.0720 - learning_rate: 4.6875e-06 - time_sec: 28.1324
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 97.1737 - mae: 13.9199 - mse: 324.8349 - val_loss: 80.4433 - val_mae: 12.1406 - val_mse: 248.9657 - learning_rate: 4.6875e-06 - time_sec: 40.9223
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 96.8313 - mae: 13.8716 - mse: 323.9571
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_50.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 117ms/step - loss: 96.1508 - mae: 13.8036 - mse: 320.2962 - val_loss: 80.4770 - val_mae: 12.1437 - val_mse: 249.4294 - learning_rate: 4.6875e-06 - time_sec: 28.5810
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 94.9334 - mae: 13.6725 - mse: 316.3527 - val_loss: 80.5405 - val_mae: 12.1499 - val_mse: 250.3069 - learning_rate: 4.6875e-06 - time_sec: 28.3001
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 100.6929 - mae: 14.3064 - mse: 341.0153 - val_loss: 80.5542 - val_mae: 12.1508 - val_mse: 250.4661 - learning_rate: 2.3438e-06 - time_sec: 28.1302
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 98.4400 - mae: 14.0527 - mse: 329.7931 - val_loss: 80.4375 - val_mae: 12.1404 - val_mse: 249.0357 - learning_rate: 2.3438e-06 - time_sec: 41.0426
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 97.1389 - mae: 13.9145 - mse: 326.2386 - val_loss: 80.4111 - val_mae: 12.1380 - val_mse: 248.6046 - learning_rate: 2.3438e-06 - time_sec: 40.9751
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 98.4314 - mae: 14.0590 - mse: 331.0834 - val_loss: 80.4615 - val_mae: 12.1422 - val_mse: 249.3637 - learning_rate: 2.3438e-06 - time_sec: 28.0942
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 96.0658 - mae: 13.7822 - mse: 321.1608 - val_loss: 80.4493 - val_mae: 12.1411 - val_mse: 249.1717 - learning_rate: 2.3438e-06 - time_sec: 28.4336
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 94.7057 - mae: 13.6461 - mse: 313.7141 - val_loss: 80.4785 - val_mae: 12.1438 - val_mse: 249.6102 - learning_rate: 1.1719e-06 - time_sec: 28.2405
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 100.3628 - mae: 14.2535 - mse: 340.5983 - val_loss: 80.4871 - val_mae: 12.1444 - val_mse: 249.7237 - learning_rate: 1.1719e-06 - time_sec: 28.2953
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 111ms/step - loss: 97.2868 - mae: 13.9357 - mse: 324.2761 - val_loss: 80.4498 - val_mae: 12.1410 - val_mse: 249.2444 - learning_rate: 1.1719e-06 - time_sec: 27.8020
# Epoch 60/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 100.5353 - mae: 14.2713 - mse: 345.5184
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_60.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 98.0671 - mae: 14.0049 - mse: 332.1097 - val_loss: 80.4274 - val_mae: 12.1391 - val_mse: 248.9253 - learning_rate: 1.1719e-06 - time_sec: 27.8164
# Epoch 61/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 99.5615 - mae: 14.1770 - mse: 334.8693 - val_loss: 80.4364 - val_mae: 12.1398 - val_mse: 249.1018 - learning_rate: 1.1719e-06 - time_sec: 28.0342
# Epoch 62/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 116ms/step - loss: 95.9566 - mae: 13.7890 - mse: 319.3817 - val_loss: 80.4335 - val_mae: 12.1396 - val_mse: 249.0194 - learning_rate: 1.0000e-06 - time_sec: 28.9815
# Epoch 63/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 92.2860 - mae: 13.4034 - mse: 301.4132 - val_loss: 80.4731 - val_mae: 12.1433 - val_mse: 249.6026 - learning_rate: 1.0000e-06 - time_sec: 28.2069
# Epoch 64/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - loss: 100.4258 - mae: 14.2586 - mse: 341.1045 - val_loss: 80.4838 - val_mae: 12.1438 - val_mse: 249.7598 - learning_rate: 1.0000e-06 - time_sec: 27.4891
# Epoch 65/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 110ms/step - loss: 96.0729 - mae: 13.8029 - mse: 317.1267 - val_loss: 80.4689 - val_mae: 12.1427 - val_mse: 249.5387 - learning_rate: 1.0000e-06 - time_sec: 27.5554
# Epoch 66/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 99.0500 - mae: 14.1060 - mse: 338.1019 - val_loss: 80.4336 - val_mae: 12.1396 - val_mse: 249.0449 - learning_rate: 1.0000e-06 - time_sec: 40.8664
# Epoch 67/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 98.4309 - mae: 14.0689 - mse: 327.3859 - val_loss: 80.4282 - val_mae: 12.1390 - val_mse: 249.0087 - learning_rate: 1.0000e-06 - time_sec: 41.0687
# Epoch 68/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 102ms/step - loss: 96.4033 - mae: 13.8125 - mse: 324.9608 - val_loss: 80.4237 - val_mae: 12.1385 - val_mse: 248.9279 - learning_rate: 1.0000e-06 - time_sec: 25.6086
# Epoch 69/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 120ms/step - loss: 93.4943 - mae: 13.5127 - mse: 307.9443 - val_loss: 80.4549 - val_mae: 12.1413 - val_mse: 249.4090 - learning_rate: 1.0000e-06 - time_sec: 29.8628
# Epoch 70/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 96.2228 - mae: 13.8135 - mse: 320.7270
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_70.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 166ms/step - loss: 99.8241 - mae: 14.1927 - mse: 338.9018 - val_loss: 80.4681 - val_mae: 12.1425 - val_mse: 249.5762 - learning_rate: 1.0000e-06 - time_sec: 40.9421
# Epoch 71/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 96.3159 - mae: 13.8347 - mse: 319.4142 - val_loss: 80.4681 - val_mae: 12.1425 - val_mse: 249.5856 - learning_rate: 1.0000e-06 - time_sec: 28.2755
# Epoch 72/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 100.3724 - mae: 14.2510 - mse: 340.5608 - val_loss: 80.4245 - val_mae: 12.1387 - val_mse: 248.9833 - learning_rate: 1.0000e-06 - time_sec: 40.9884
# Epoch 73/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 97.9512 - mae: 14.0223 - mse: 324.6372 - val_loss: 80.4206 - val_mae: 12.1383 - val_mse: 248.9634 - learning_rate: 1.0000e-06 - time_sec: 40.8993
# Epoch 74/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 96.2891 - mae: 13.8230 - mse: 322.1871 - val_loss: 80.4238 - val_mae: 12.1385 - val_mse: 248.9982 - learning_rate: 1.0000e-06 - time_sec: 26.9031
# Epoch 75/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 93.3808 - mae: 13.5168 - mse: 308.1958 - val_loss: 80.4581 - val_mae: 12.1416 - val_mse: 249.4938 - learning_rate: 1.0000e-06 - time_sec: 41.0080
# Epoch 76/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 99.4664 - mae: 14.1517 - mse: 336.5176 - val_loss: 80.4567 - val_mae: 12.1415 - val_mse: 249.4761 - learning_rate: 1.0000e-06 - time_sec: 40.9099
# Epoch 77/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 97.2261 - mae: 13.9402 - mse: 322.6153 - val_loss: 80.4676 - val_mae: 12.1423 - val_mse: 249.6356 - learning_rate: 1.0000e-06 - time_sec: 28.0514
# Epoch 78/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 99.0914 - mae: 14.1081 - mse: 335.2503 - val_loss: 80.4219 - val_mae: 12.1385 - val_mse: 249.0081 - learning_rate: 1.0000e-06 - time_sec: 28.2804
# Epoch 79/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 98.2000 - mae: 14.0325 - mse: 328.7655 - val_loss: 80.4150 - val_mae: 12.1379 - val_mse: 248.9158 - learning_rate: 1.0000e-06 - time_sec: 40.9148
# Epoch 80/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 98.8719 - mae: 14.1090 - mse: 334.0084
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_80.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 114ms/step - loss: 96.7899 - mae: 13.8822 - mse: 324.7027 - val_loss: 80.4211 - val_mae: 12.1382 - val_mse: 249.0353 - learning_rate: 1.0000e-06 - time_sec: 27.8195
# Epoch 81/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 116ms/step - loss: 93.6290 - mae: 13.5229 - mse: 308.7932 - val_loss: 80.4303 - val_mae: 12.1391 - val_mse: 249.1547 - learning_rate: 1.0000e-06 - time_sec: 28.9758
# Epoch 82/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 96.6754 - mae: 13.8653 - mse: 324.2084 - val_loss: 80.4449 - val_mae: 12.1406 - val_mse: 249.3441 - learning_rate: 1.0000e-06 - time_sec: 28.3259
# Epoch 83/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - loss: 98.5059 - mae: 14.0676 - mse: 328.6386 - val_loss: 80.4567 - val_mae: 12.1414 - val_mse: 249.5218 - learning_rate: 1.0000e-06 - time_sec: 28.0274
# Epoch 84/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 99.2576 - mae: 14.1327 - mse: 336.4356 - val_loss: 80.4118 - val_mae: 12.1373 - val_mse: 249.0018 - learning_rate: 1.0000e-06 - time_sec: 40.9797
# Epoch 85/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 98.0410 - mae: 14.0101 - mse: 330.0807 - val_loss: 80.3955 - val_mae: 12.1360 - val_mse: 248.7472 - learning_rate: 1.0000e-06 - time_sec: 28.4449
# Epoch 86/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - loss: 97.9813 - mae: 14.0052 - mse: 328.3920 - val_loss: 80.4143 - val_mae: 12.1375 - val_mse: 248.9967 - learning_rate: 1.0000e-06 - time_sec: 28.3839
# Epoch 87/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 95.3605 - mae: 13.7153 - mse: 317.8345 - val_loss: 80.4210 - val_mae: 12.1382 - val_mse: 249.0408 - learning_rate: 1.0000e-06 - time_sec: 40.9455
# Epoch 88/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 115ms/step - loss: 94.9880 - mae: 13.6730 - mse: 314.0731 - val_loss: 80.4419 - val_mae: 12.1402 - val_mse: 249.3648 - learning_rate: 1.0000e-06 - time_sec: 28.7627
# Epoch 89/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - loss: 100.1589 - mae: 14.2437 - mse: 338.0598 - val_loss: 80.4422 - val_mae: 12.1401 - val_mse: 249.3824 - learning_rate: 1.0000e-06 - time_sec: 28.2654
# Epoch 90/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 95.7621 - mae: 13.7696 - mse: 317.5438
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_90.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 166ms/step - loss: 97.8691 - mae: 13.9894 - mse: 328.5788 - val_loss: 80.4116 - val_mae: 12.1375 - val_mse: 248.9802 - learning_rate: 1.0000e-06 - time_sec: 40.9379
# Epoch 91/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 110ms/step - loss: 97.6805 - mae: 13.9724 - mse: 328.3220 - val_loss: 80.3943 - val_mae: 12.1358 - val_mse: 248.7631 - learning_rate: 1.0000e-06 - time_sec: 27.5622
# Epoch 92/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - loss: 98.8295 - mae: 14.0976 - mse: 332.1689 - val_loss: 80.4148 - val_mae: 12.1377 - val_mse: 248.9817 - learning_rate: 1.0000e-06 - time_sec: 27.2343
# Epoch 93/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 162ms/step - loss: 96.2811 - mae: 13.8201 - mse: 322.6949 - val_loss: 80.4102 - val_mae: 12.1372 - val_mse: 248.8985 - learning_rate: 1.0000e-06 - time_sec: 40.3531
# Epoch 94/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - loss: 93.5057 - mae: 13.5324 - mse: 308.0600 - val_loss: 80.4346 - val_mae: 12.1394 - val_mse: 249.3244 - learning_rate: 1.0000e-06 - time_sec: 27.2268
# Epoch 95/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 110ms/step - loss: 101.0863 - mae: 14.3394 - mse: 343.8851 - val_loss: 80.4500 - val_mae: 12.1409 - val_mse: 249.4680 - learning_rate: 1.0000e-06 - time_sec: 27.4084
# Epoch 96/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 95.7529 - mae: 13.7742 - mse: 315.6548 - val_loss: 80.4254 - val_mae: 12.1386 - val_mse: 249.1809 - learning_rate: 1.0000e-06 - time_sec: 27.0565
# Epoch 97/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 98.3917 - mae: 14.0354 - mse: 333.3885 - val_loss: 80.4013 - val_mae: 12.1365 - val_mse: 248.8262 - learning_rate: 1.0000e-06 - time_sec: 26.9503
# Epoch 98/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - loss: 99.2522 - mae: 14.1525 - mse: 332.6991 - val_loss: 80.4097 - val_mae: 12.1372 - val_mse: 248.9349 - learning_rate: 1.0000e-06 - time_sec: 26.9734
# Epoch 99/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - loss: 96.8350 - mae: 13.8656 - mse: 326.7567 - val_loss: 80.4018 - val_mae: 12.1364 - val_mse: 248.7886 - learning_rate: 1.0000e-06 - time_sec: 41.0247
# Epoch 100/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 92.8831 - mae: 13.4599 - mse: 302.0098
#  Saved: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/checkpoint_ECG_LSTM_epoch_100.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 120ms/step - loss: 92.9742 - mae: 13.4676 - mse: 303.9816 - val_loss: 80.4449 - val_mae: 12.1403 - val_mse: 249.4584 - learning_rate: 1.0000e-06 - time_sec: 29.5543

# %%
import matplotlib.pyplot as plt

hist = history.history

plt.figure(figsize=(7,4))
plt.plot(hist["loss"], label="train_loss")
plt.plot(hist["val_loss"], label="val_loss")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend(); plt.title("Loss Curve")
plt.show()

plt.figure(figsize=(7,4))
plt.plot(hist["mae"], label="train_mae")
plt.plot(hist["val_mae"], label="val_mae")
plt.xlabel("Epoch"); plt.ylabel("MAE"); plt.legend(); plt.title("MAE Curve")
plt.show()

plt.figure(figsize=(7,4))
plt.plot(hist["mse"], label="train_mse")
plt.plot(hist["val_mse"], label="val_mse")
plt.xlabel("Epoch"); plt.ylabel("MSE"); plt.legend(); plt.title("MSE Curve")
plt.show()

# %%
# ================== Cell 10 — Evaluate BEST on test + extra testing figures ==================
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

best_model = tf.keras.models.load_model(best_path)

test_loss, test_mae, test_mse = best_model.evaluate(test_data, verbose=0)

y_true, y_pred = [], []
for xb, yb in test_data:
    y_true.append(yb.numpy())
    y_pred.append(best_model.predict(xb, verbose=0))

y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)

mae_sbp = float(np.mean(np.abs(y_pred[:,0] - y_true[:,0])))
mae_dbp = float(np.mean(np.abs(y_pred[:,1] - y_true[:,1])))

mse_sbp = float(np.mean((y_pred[:,0] - y_true[:,0])**2))
mse_dbp = float(np.mean((y_pred[:,1] - y_true[:,1])**2))

print("", run_name)
print("Test loss:", float(test_loss))
print("Test MAE :", float(test_mae))
print("Test MSE :", float(test_mse))
print("MAE SBP  :", mae_sbp)
print("MAE DBP  :", mae_dbp)
print("MSE SBP  :", mse_sbp)
print("MSE DBP  :", mse_dbp)
print("Saved best:", best_path)

# -------- (A) Scatter: Pred vs True --------
plt.figure(figsize=(6,5))
plt.scatter(y_true[:,0], y_pred[:,0], s=6)
plt.xlabel("True SBP"); plt.ylabel("Pred SBP"); plt.title("SBP: True vs Pred")
plt.grid(True); plt.show()

plt.figure(figsize=(6,5))
plt.scatter(y_true[:,1], y_pred[:,1], s=6)
plt.xlabel("True DBP"); plt.ylabel("Pred DBP"); plt.title("DBP: True vs Pred")
plt.grid(True); plt.show()

# -------- (B) Error histograms --------
err_sbp = y_pred[:,0] - y_true[:,0]
err_dbp = y_pred[:,1] - y_true[:,1]

plt.figure(figsize=(7,4))
plt.hist(err_sbp, bins=50)
plt.title("SBP Residuals (Pred-True)"); plt.xlabel("mmHg"); plt.ylabel("count")
plt.show()

plt.figure(figsize=(7,4))
plt.hist(err_dbp, bins=50)
plt.title("DBP Residuals (Pred-True)"); plt.xlabel("mmHg"); plt.ylabel("count")
plt.show()

# -------- (C) Bland–Altman --------
def bland_altman(y_true_1d, y_pred_1d, title):
    mean_bp = (y_true_1d + y_pred_1d) / 2.0
    diff    = (y_pred_1d - y_true_1d)
    md = diff.mean()
    sd = diff.std()
    loa1 = md - 1.96*sd
    loa2 = md + 1.96*sd

    plt.figure(figsize=(6,5))
    plt.scatter(mean_bp, diff, s=6)
    plt.axhline(md, linestyle="--")
    plt.axhline(loa1, linestyle="--")
    plt.axhline(loa2, linestyle="--")
    plt.xlabel("Mean of True & Pred"); plt.ylabel("Pred - True (mmHg)")
    plt.title(title)
    plt.grid(True); plt.show()

bland_altman(y_true[:,0], y_pred[:,0], "Bland–Altman: SBP")
bland_altman(y_true[:,1], y_pred[:,1], "Bland–Altman: DBP")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
#  ECG_LSTM
# Test loss: 11.284908294677734
# Test MAE : 11.775114059448242
# Test MSE : 227.29818725585938
# MAE SBP  : 14.162463188171387
# MAE DBP  : 9.387768745422363
# MSE SBP  : 311.47259521484375
# MSE DBP  : 143.1236572265625
# Saved best: /content/drive/MyDrive/mimic_bp/single_modality_runs/ECG_LSTM/best_ECG_LSTM.keras
